# %%
from good_agent import Agent
from good_agent.events import AgentEvents, MessageAppendParams
from good_agent.core.event_router import EventContext, on

# %%
class SidecarAgent(Agent):

    @on(AgentEvents.MESSAGE_APPEND_BEFORE)
    async def on_before_message_append(
        self,
        ctx: EventContext[MessageAppendParams, None],
    ):
        pass

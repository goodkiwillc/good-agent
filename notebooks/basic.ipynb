# %%
from good_agent import Agent
# Out:
# 2025-11-04 09:41:28.986 | DEBUG    | good_common.types.url_cython_integration:auto_enable_optimization:366 - URL Cython optimization auto-enabled successfully

# %%
async with Agent(
    "You are a helpful assistant.",
) as agent:
    message = await agent.call("What is the capital of France?")
    agent.print(message)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 async with Agent(
#       2     "You are a helpful assistant.",
#       3 ) as agent:
# ----> 4     message = await agent.call("What is the capital of France?")
#       5     agent.print(message)
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/agent.py:262, in ensure_ready.<locals>.async_wrapper(self, *args, **kwargs)
#     259 # Await and return the result
#     260 # Use getattr to bypass type checker's argument analysis
#     261 method = getattr(func, "__call__", func)  # noqa: B004
# --> 262 return await method(self, *args, **kwargs)
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/agent.py:2028, in Agent.call(self, role, response_model, context, auto_execute_tools, *content_parts, **kwargs)
#    2026 final_message = None
#    2027 last_assistant_message = None
# -> 2028 async for message in self.execute(**kwargs):
#    2029     match message:
#    2030         case AssistantMessage() | AssistantMessageStructuredOutput():
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/agent.py:249, in ensure_ready.<locals>.async_gen_wrapper(self, *args, **kwargs)
#     246 # Yield from the generator
#     247 # Use getattr to bypass type checker's argument analysis
#     248 method = getattr(func, "__call__", func)  # noqa: B004
# --> 249 async for item in method(self, *args, **kwargs):  # type: ignore[misc]
#     250     yield item
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/agent.py:2260, in Agent.execute(self, streaming, max_iterations, **kwargs)
#    2252 self.do(
#    2253     AgentEvents.EXECUTE_ITERATION_BEFORE,
#    2254     agent=self,
#    2255     iteration=iterations,
#    2256     messages_count=len(self.messages),
#    2257 )
#    2259 # Call the LLM to get next response (without auto-executing tools)
# -> 2260 response = await self._llm_call(**kwargs)
#    2261 iterations += 1
#    2263 # Set iteration index
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/agent.py:1741, in Agent._llm_call(self, response_model, **kwargs)
#    1737 else:
#    1738     # Use complete for regular chat
#    1739     _messages = await self.model.format_message_list_for_llm(self.messages)
# -> 1741     llm_response = await self.model.complete(
#    1742         _messages,
#    1743         **kwargs,
#    1744     )
#    1746 choice = llm_response.choices[0]
#    1748 assert _is_choices_instance(choice)
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/model/llm.py:1542, in LanguageModel.complete(self, messages, stream, **kwargs)
#    1531 ctx = await self.agent.apply_typed(
#    1532     AgentEvents.LLM_COMPLETE_BEFORE,
#    1533     CompletionEvent,
#    (...)   1537     llm=self,
#    1538 )
#    1540 try:
#    1541     # Router already handles retries/fallbacks via model_list configuration
# -> 1542     response = await self.router.acompletion(
#    1543         messages=ctx.parameters["messages"],
#    1544         **ctx.parameters["config"],
#    1545     )
#    1546     # Usage is updated in async_log_success_event callback
#    1547
#    1548     # Fire after event
#    1549     end_time = time.time()
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/model/manager.py:228, in get_managed_router_class.<locals>._ManagedRouter.acompletion(self, *args, **kwargs)
#     220 await self._invoke_async_callbacks(
#     221     "async_log_pre_api_call",
#     222     kwargs.get("model", args[0] if args else None),
#     223     args[1] if len(args) > 1 else kwargs.get("messages", []),
#     224     kwargs,
#     225 )
#     227 # Make the actual request to the parent Router
# --> 228 result = await super().acompletion(*args, **kwargs)
#     230 # After successful request
#     231 import time
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/llm_client/compat.py:91, in Router.acompletion(self, messages, model, stream, **kwargs)
#      88 if messages and isinstance(messages[0], dict):
#      89     messages = [Message(**msg) if isinstance(msg, dict) else msg for msg in messages]
# ---> 91 response = await super().acompletion(
#      92     messages=messages,  # type: ignore
#      93     model=model,
#      94     stream=stream,
#      95     **kwargs
#      96 )
#      98 # Convert choices dicts to Choices objects for compatibility
#      99 if hasattr(response, 'choices') and response.choices:
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/llm_client/router.py:327, in Router.acompletion(self, *args, **kwargs)
#     325 async def acompletion(self, *args: Any, **kwargs: Any) -> ChatResponse:
#     326     """Alias for completion() for litellm compatibility."""
# --> 327     return await self.completion(*args, **kwargs)
#
# File ~/Code/GoodKiwi/projects/good-agent/src/good_agent/llm_client/router.py:285, in Router.completion(self, messages, model, stream, **kwargs)
#     283 # All models failed
#     284 self.stats["failed_requests"] += 1
# --> 285 raise Exception(f"All models failed. Last error: {last_error}")
#
# Exception: All models failed. Last error: Error code: 401 - {'error': {'message': "You didn't provide an API key. You need to provide your API key in an Authorization header using Bearer auth (i.e. Authorization: Bearer YOUR_KEY), or as the password field (with blank username) if you're accessing the API from your browser and are prompted for a username and password. You can obtain an API key from https://platform.openai.com/account/api-keys.", 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %%
from good_agent import Agent
# Out:
# 2025-11-05 13:42:12.414 | DEBUG    | good_common.types.url_cython_integration:auto_enable_optimization:366 - URL Cython optimization auto-enabled successfully

# %%
async with Agent(
    "You are a helpful assistant.",
    template_functions=
) as agent:
    message = await agent.call("What is the capital of France?")
    agent.print(message)
# Out:
# ╭────────────────────────────────────────────────── @assistant ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  The capital of France is Paris.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
